# %%
import pandas as pd

# %%
data = pd.read_csv("bill_authentication.csv")

# %%
data.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data.shape
# Out:
# (1372, 5)

# %%
x = data.drop("Class", axis=1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
from sklearn.svm import SVC
sv = SVC(kernel = 'sigmoid')

# %%
#training the model
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = sv.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[112  57]
#  [ 35  71]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.66      0.71       169
#            1       0.55      0.67      0.61       106
#
#     accuracy                           0.67       275
#    macro avg       0.66      0.67      0.66       275
# weighted avg       0.68      0.67      0.67       275

# %% [markdown]
# ## Changing testing set to 30%

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = sv.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[168  71]
#  [ 68 105]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.70      0.71       239
#            1       0.60      0.61      0.60       173
#
#     accuracy                           0.66       412
#    macro avg       0.65      0.65      0.65       412
# weighted avg       0.66      0.66      0.66       412

# %%
## Changing testing data to 35%

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.35)

# %%
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = sv.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[191  83]
#  [ 81 126]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       274
#            1       0.60      0.61      0.61       207
#
#     accuracy                           0.66       481
#    macro avg       0.65      0.65      0.65       481
# weighted avg       0.66      0.66      0.66       481

# %% [markdown]
# ## Changing testing dataset to 40%

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.40)

# %%
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = sv.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[219  85]
#  [ 80 165]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73       304
#            1       0.66      0.67      0.67       245
#
#     accuracy                           0.70       549
#    macro avg       0.70      0.70      0.70       549
# weighted avg       0.70      0.70      0.70       549
